# %%
import numpy as np
import matplotlib.pyplot as plt
import random
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# %%
imagepath0 = '../input/all-dogs/pics/'
imagepath1 = '../input/all-dogs-crop/pics/'
imagepath2 = '../input/all-dogs-crop2-64/pics/'

# %%
picnames = []
randompics = []
picnum = 50

for i in range(picnum):
    file  = random.choice(os.listdir(imagepath1))
    picname = imagepath1 + file
    img = mpimg.imread(picname)
    randompics.append(img)

# %%
fig, axes = plt.subplots(5, 10, figsize=(15, 8),
                         subplot_kw={'xticks': (), 'yticks': ()})

for image, ax in zip(randompics, axes.ravel()):
    ax.imshow(image)

# %%
picnames = []
randompics = []
picnum = 50

for i in range(picnum):
    file  = random.choice(os.listdir(imagepath0))
    picname = imagepath0 + file
    img = mpimg.imread(picname)
    randompics.append(img)
    
fig, axes = plt.subplots(5, 10, figsize=(15, 8),
                         subplot_kw={'xticks': (), 'yticks': ()})

for image, ax in zip(randompics, axes.ravel()):
    ax.imshow(image)

# %%
picnames = []
randompics = []
picnum = 50

for i in range(picnum):
    file  = random.choice(os.listdir(imagepath2))
    picname = imagepath2 + file
    img = mpimg.imread(picname)
    randompics.append(img)
    
fig, axes = plt.subplots(5, 10, figsize=(15, 8),
                         subplot_kw={'xticks': (), 'yticks': ()})

for image, ax in zip(randompics, axes.ravel()):
    ax.imshow(image)
